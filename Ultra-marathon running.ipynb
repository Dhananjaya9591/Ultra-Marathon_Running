# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# Load The Data

# %%
df = pd.read_csv("A:/Python/Extra source/TWO_CENTURIES_OF_UM_RACES.csv",low_memory=False)

# %%
df.head(10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286           0
# 1                 9.501           1
# 2                 9.472           2
# 3                 8.976           3
# 4                 8.469           4
# 5                 7.792           5
# 6                 7.732           6
# 7                 7.645           7
# 8                 7.516           8
# 9                 7.404           9

# %%
# Complete Data Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7461195 entries, 0 to 7461194
# Data columns (total 13 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Year of event              int64
#  1   Event dates                object
#  2   Event name                 object
#  3   Event distance/length      object
#  4   Event number of finishers  int64
#  5   Athlete performance        object
#  6   Athlete club               object
#  7   Athlete country            object
#  8   Athlete year of birth      float64
#  9   Athlete gender             object
#  10  Athlete age category       object
#  11  Athlete average speed      object
#  12  Athlete ID                 int64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 740.0+ MB

# %%
# Check Data Types

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461089                  50km                          6           4:19:56 h
# 7461090                  50km                          6           4:28:57 h
# 7461091                  50km                          6           4:46:39 h
# 7461092                  50km                          6           4:47:39 h
# 7461093                  50km                          6           5:58:16 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461089                *QLD             AUS                 1956.0
# 7461090                *QLD             AUS                 1954.0
# 7461091                *QLD             AUS                 1951.0
# 7461092                *QLD             AUS                 1939.0
# 7461093                *QLD             AUS                 1938.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461089              F                  W35               11541.0     1046326
# 7461090              M                  M40               11154.0     1070007
# 7461091              M                  M40               10466.0      345672
# 7461092              M                  M55               10429.0     1082443
# 7461093              F                  W55                8374.0     1082581
#
# [1522609 rows x 13 columns]

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [352181 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km','50mi'])]
# Out:
#          Year of event Event dates                        Event name  \
# 0                 2018  06.01.2018               Selva Costera (CHI)
# 1                 2018  06.01.2018               Selva Costera (CHI)
# 2                 2018  06.01.2018               Selva Costera (CHI)
# 3                 2018  06.01.2018               Selva Costera (CHI)
# 4                 2018  06.01.2018               Selva Costera (CHI)
# ...                ...         ...                               ...
# 7461181           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461182           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461183           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461184           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
# 7461185           1995  07.01.1995  Avalon Benefit 50-Mile Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 7461181                  50mi                         92          11:59:37 h
# 7461182                  50mi                         92          12:01:41 h
# 7461183                  50mi                         92          12:03:26 h
# 7461184                  50mi                         92          12:03:26 h
# 7461185                  50mi                         92          12:05:59 h
#
#                Athlete club Athlete country  Athlete year of birth  \
# 0                     Tnfrc             CHI                 1978.0
# 1        Roberto Echeverría             CHI                 1981.0
# 2         Puro Trail Osorno             CHI                 1987.0
# 3                  Columbia             ARG                 1976.0
# 4            Baguales Trail             CHI                 1992.0
# ...                     ...             ...                    ...
# 7461181                 NaN             USA                 1941.0
# 7461182                 NaN             USA                 1932.0
# 7461183                 NaN             USA                 1934.0
# 7461184                 NaN             USA                 1951.0
# 7461185                 NaN             USA                 1947.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286           0
# 1                    M                  M35                 9.501           1
# 2                    M                  M23                 9.472           2
# 3                    M                  M40                 8.976           3
# 4                    M                  M23                 8.469           4
# ...                ...                  ...                   ...         ...
# 7461181              M                  M50                6709.0     1045603
# 7461182              M                  M60                6690.0     1070463
# 7461183              F                  W60                6674.0      416139
# 7461184              F                  W40                6674.0     1098098
# 7461185              F                  W45                6650.0     1626367
#
# [1874790 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event']==2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...                                          ...                   ...
# 2762404               Bison Ultra-Trail 50 (POL)                  50km
# 2762405               Bison Ultra-Trail 50 (POL)                  50km
# 2762406               Bison Ultra-Trail 50 (POL)                  50km
# 2762407               Bison Ultra-Trail 50 (POL)                  50km
# 2762408               Bison Ultra-Trail 50 (POL)                  50km
#
#          Event number of finishers Athlete performance          Athlete club  \
# 2538571                         38           7:34:19 h                   日本隊
# 2538572                         38           7:43:50 h                   NaN
# 2538573                         38           8:04:40 h                   NaN
# 2538574                         38           8:30:49 h             台灣大腳ㄚ長跑協會
# 2538575                         38           8:34:47 h                   NaN
# ...                            ...                 ...                   ...
# 2762404                        271           7:36:25 h  AKS Polonia Warszawa
# 2762405                        271           7:36:27 h             *Warszawa
# 2762406                        271           7:44:18 h      Outdoor Training
# 2762407                        271           8:04:50 h      PH Bysewo Gdańsk
# 2762408                        271           8:11:43 h    *Nowe Aleksandrowo
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
# ...                 ...                    ...            ...
# 2762404             POL                 1981.0              F
# 2762405             POL                 1970.0              F
# 2762406             POL                 1993.0              F
# 2762407             POL                 1976.0              M
# 2762408             POL                 1961.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627       53107
# 2538572                  M45                10.409        8785
# 2538573                  M40                 9.962        4502
# 2538574                  W50                 9.452       63964
# 2538575                  M55                 9.379        4485
# ...                      ...                   ...         ...
# 2762404                  W35                 6.573      860743
# 2762405                  W45                 6.572      860744
# 2762406                  W23                 6.461      860745
# 2762407                  M40                 6.188      798409
# 2762408                  M55                 6.101      860746
#
# [63489 rows x 13 columns]

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 7461181               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461182               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461183               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461184               Avalon Benefit 50-Mile Run (USA)                  50mi
# 7461185               Avalon Benefit 50-Mile Run (USA)                  50mi
#
#          Event number of finishers Athlete performance      Athlete club  \
# 55                               9           9:53:05 h  *Middleville, MI
# 56                               9          11:09:35 h     *Waterloo, ON
# 57                               9          11:33:00 h    *Kitchener, ON
# 58                               9          11:38:17 h        *Utica, MI
# 59                               9          11:56:35 h   *Grass Lake, MI
# ...                            ...                 ...               ...
# 7461181                         92          11:59:37 h               NaN
# 7461182                         92          12:01:41 h               NaN
# 7461183                         92          12:03:26 h               NaN
# 7461184                         92          12:03:26 h               NaN
# 7461185                         92          12:05:59 h               NaN
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 7461181             USA                 1941.0              M
# 7461182             USA                 1932.0              M
# 7461183             USA                 1934.0              F
# 7461184             USA                 1951.0              F
# 7461185             USA                 1947.0              F
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141          55
# 56                       W40                 7.211          56
# 57                       M40                 6.967          57
# 58                       M23                 6.914          58
# 59                       M23                 6.738          59
# ...                      ...                   ...         ...
# 7461181                  M50                6709.0     1045603
# 7461182                  M60                6690.0     1070463
# 7461183                  W60                6674.0      416139
# 7461184                  W40                6674.0     1098098
# 7461185                  W45                6650.0     1626367
#
# [1398540 rows x 13 columns]

# %%
df2 = df[(df['Event distance/length'].isin(['50km','50mi']))  & (df['Year of event']==2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539951  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539952  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539953  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539954  West Seattle Beach Run - Winter Edition (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# 2539949                         20           4:27:34 h
# 2539950                         20           4:42:06 h
# 2539951                         20           4:49:20 h
# 2539952                         20           4:49:50 h
# 2539953                         20           4:51:00 h
# 2539954                         20           5:02:35 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# 2539950            *Seattle, WA             USA                 1985.0
# 2539951      *Camano Island, WA             USA                 1961.0
# 2539952            *Clinton, WA             USA                 1970.0
# 2539953            *Seattle, WA             USA                 1975.0
# 2539954          *Sammamish, WA             USA                 1979.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281
# 2539950              F                  W23                10.635      810282
# 2539951              M                  M55                10.369       11739
# 2539952              M                  M45                10.351       80394
# 2539953              F                  W40                10.309      140909
# 2539954              M                  M40                 9.915      753889

# %%
df2.shape
# Out:
# (26090, 13)

# %%
 df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
df2.loc[:, 'Event name']= df2['Event name'].str.split('(').str.get(0)

# %%
df2.head(5)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 2539945                  50km                         20           3:17:55 h
# 2539946                  50km                         20           4:02:32 h
# 2539947                  50km                         20           4:07:57 h
# 2539948                  50km                         20           4:22:02 h
# 2539949                  50km                         20           4:27:34 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158       71287
# 2539946              M                  M35                12.369      629508
# 2539947              M                 MU23                12.099       64838
# 2539948              M                  M35                11.449      704450
# 2539949              M                  M40                11.212      810281

# %%
# clean up Athlete  age

# %%
# Remove h from athlete performance

# %%
df2['Athlete performance'].str.split(' ').str.get(0)
# Out:
# 2746390    10:40:56
# 2577434     7:49:40
# 2589048     3:27:48
# 2745828     8:46:37
# 2592144    12:59:01
#              ...
# 2746543     8:31:26
# 2749869    11:55:05
# 2755985     9:03:25
# 2755994    10:37:00
# 2755997    12:30:00
# Name: Athlete performance, Length: 26090, dtype: object

# %%
df2.head(5)
# Out:
#          Year of event     Event dates  \
# 2746390           2020      17.10.2020
# 2577434           2020      12.07.2020
# 2589048           2020      14.03.2020
# 2745828           2020  17.-18.10.2020
# 2592144           2020      14.03.2020
#
#                                      Event name Event distance/length  \
# 2746390              Pumpkin Holler 50 Km Race                   50km
# 2577434  Cremator Ultra 50 Mile Endurance Race                   50mi
# 2589048   Peyton's Wild and Wacky 10x5Km Ultra                   50km
# 2745828          Cloudsplitter 100 - 50 Km Run                   50km
# 2592144                Antelope Canyon 50 Mile                   50mi
#
#          Event number of finishers Athlete performance         Athlete club  \
# 2746390                        105            10:40:56        *Stilwell, OK
# 2577434                          7             7:49:40  *South Carolina, SC
# 2589048                         75             3:27:48  *South Carolina, SC
# 2745828                         66             8:46:37           *Niota, TN
# 2592144                        266            12:59:01      *Antigonish, NS
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2746390             USA                 2011.0              F
# 2577434             USA                 2008.0              M
# 2589048             USA                 2008.0              M
# 2745828             USA                 2008.0              M
# 2592144             USA                 2007.0              F
#
#         Athlete age category Athlete average speed  Athlete ID  Athlete age
# 2746390                 WU23                 4.681      857217          9.0
# 2577434                 MU23                 10.28      325504         12.0
# 2589048                 MU23                14.437      325504         12.0
# 2745828                 MU23                 5.697      857061         12.0
# 2592144                 WU23                 6.198      820935         13.0

# %%
# drop columns : athlete club , athlete country , athlete year of birth , athlete age category

# %%
df2 = df2.drop(['Athlete club','Athlete country','Athlete year of birth','Athlete age category'],axis = 1)

# %%
df2.head(5)
# Out:
#          Year of event     Event dates  \
# 2746390           2020      17.10.2020
# 2577434           2020      12.07.2020
# 2589048           2020      14.03.2020
# 2745828           2020  17.-18.10.2020
# 2592144           2020      14.03.2020
#
#                                      Event name Event distance/length  \
# 2746390              Pumpkin Holler 50 Km Race                   50km
# 2577434  Cremator Ultra 50 Mile Endurance Race                   50mi
# 2589048   Peyton's Wild and Wacky 10x5Km Ultra                   50km
# 2745828          Cloudsplitter 100 - 50 Km Run                   50km
# 2592144                Antelope Canyon 50 Mile                   50mi
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2746390                        105            10:40:56              F
# 2577434                          7             7:49:40              M
# 2589048                         75             3:27:48              M
# 2745828                         66             8:46:37              M
# 2592144                        266            12:59:01              F
#
#         Athlete average speed  Athlete ID  Athlete age
# 2746390                 4.681      857217          9.0
# 2577434                 10.28      325504         12.0
# 2589048                14.437      325504         12.0
# 2745828                 5.697      857061         12.0
# 2592144                 6.198      820935         13.0

# %%
# clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                  0
# Event dates                    0
# Event name                     0
# Event distance/length          0
# Event number of finishers      0
# Athlete performance            0
# Athlete gender                 0
# Athlete average speed          0
# Athlete ID                     0
# Athlete age                  233
# dtype: int64

# %%
df2 = df2.dropna()

# %%
df2.isnull().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# Athlete age                  0
# dtype: int64

# %%
# checking the Duplicates

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
# reset index

# %%
df2.reset_index(drop=True)
# Out:
#        Year of event     Event dates                              Event name  \
# 0               2020      17.10.2020              Pumpkin Holler 50 Km Race
# 1               2020      12.07.2020  Cremator Ultra 50 Mile Endurance Race
# 2               2020      14.03.2020   Peyton's Wild and Wacky 10x5Km Ultra
# 3               2020  17.-18.10.2020          Cloudsplitter 100 - 50 Km Run
# 4               2020      14.03.2020                Antelope Canyon 50 Mile
# ...              ...             ...                                     ...
# 25852           2020      11.01.2020               Avalon Benefit 50 Km Run
# 25853           2020  08.-09.02.2020           Grandmaster Ultras 50 Km Run
# 25854           2020      14.03.2020             Everglades 50 km Ultra Run
# 25855           2020      08.02.2020                  Rocky 50 Km Trail Run
# 25856           2020      25.01.2020          Angela Ivory 50K Memorial Run
#
#       Event distance/length  Event number of finishers Athlete performance  \
# 0                      50km                        105            10:40:56
# 1                      50mi                          7             7:49:40
# 2                      50km                         75             3:27:48
# 3                      50km                         66             8:46:37
# 4                      50mi                        266            12:59:01
# ...                     ...                        ...                 ...
# 25852                  50km                        293            12:01:46
# 25853                  50km                          9            12:02:10
# 25854                  50km                         63             8:50:11
# 25855                  50km                        158            13:34:44
# 25856                  50km                         23             9:52:00
#
#       Athlete gender Athlete average speed  Athlete ID  Athlete age
# 0                  F                 4.681      857217          9.0
# 1                  M                 10.28      325504         12.0
# 2                  M                14.437      325504         12.0
# 3                  M                 5.697      857061         12.0
# 4                  F                 6.198      820935         13.0
# ...              ...                   ...         ...          ...
# 25852              M                 4.156       65153         81.0
# 25853              M                 4.154      394643         81.0
# 25854              M                 5.658       46463         82.0
# 25855              M                 3.682       76752         82.0
# 25856              M                 5.068       64748         85.0
#
# [25857 rows x 10 columns]

# %%
# fix Types

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                     int64
# Athlete age                  float64
# dtype: object

# %%
df2['Athlete age'] = df2['Athlete age'].astype(int,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df2['Athlete age'] = df2['Athlete age'].astype(int , inplace = True)
#
# TypeError: NDFrame.astype() got an unexpected keyword argument 'inplace'

# %%
 df2['Athlete age'].astype(int)
# Out:
# 2746390     9
# 2577434    12
# 2589048    12
# 2745828    12
# 2592144    13
#            ..
# 2563553    81
# 2627971    81
# 2588736    82
# 2629941    82
# 2547499    85
# Name: Athlete age, Length: 25857, dtype: int32

# %%
df2['Athlete average speed'].astype(float)
# Out:
# 2746390     4.681
# 2577434    10.280
# 2589048    14.437
# 2745828     5.697
# 2592144     6.198
#             ...
# 2563553     4.156
# 2627971     4.154
# 2588736     5.658
# 2629941     3.682
# 2547499     5.068
# Name: Athlete average speed, Length: 25857, dtype: float64

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# Athlete age                    int32
# dtype: object

# %% [raw]
# # Rename the columns
#
# Year of event
# Year of event
# Event name
# Event distance/length
# Event number of finishers
# Athlete performance
# Athlete gender
# Athlete average speed
# Athlete ID
# Athlete age

# %%
df2 = df2.rename(columns = { 'Year of event':'Year',
                            'Year of event':'Race_Day',
                            'Event name ':'Race_Name',
                            'Event distance/length':'Race_Length',
                            'Event number of finishers ':'Race_NO_of_Finisher'
                           })

# %%
df2.columns
# Out:
# Index(['Race_Day', 'Event dates', 'Event name', 'Race_Length',
#        'Event number of finishers', 'Athlete performance', 'Athlete gender',
#        'Athlete average speed', 'Athlete ID', 'Athlete age'],
#       dtype='object')

# %%
df2.head()
# Out:
#          Race_Day     Event dates                              Event name  \
# 2746390      2020      17.10.2020              Pumpkin Holler 50 Km Race
# 2577434      2020      12.07.2020  Cremator Ultra 50 Mile Endurance Race
# 2589048      2020      14.03.2020   Peyton's Wild and Wacky 10x5Km Ultra
# 2745828      2020  17.-18.10.2020          Cloudsplitter 100 - 50 Km Run
# 2592144      2020      14.03.2020                Antelope Canyon 50 Mile
#
#         Race_Length  Event number of finishers Athlete performance  \
# 2746390        50km                        105            10:40:56
# 2577434        50mi                          7             7:49:40
# 2589048        50km                         75             3:27:48
# 2745828        50km                         66             8:46:37
# 2592144        50mi                        266            12:59:01
#
#         Athlete gender  Athlete average speed  Athlete ID  Athlete age
# 2746390              F                  4.681      857217            9
# 2577434              M                 10.280      325504           12
# 2589048              M                 14.437      325504           12
# 2745828              M                  5.697      857061           12
# 2592144              F                  6.198      820935           13

# %%
df2[df2['Athlete ID'] == 222509]
# Out:
#          Race_Day Event dates                     Event name Race_Length  \
# 2616900      2020  22.02.2020       Manasota Track Club 50K         50km
# 2591482      2020  14.03.2020  Everglades 50 Mile Ultra Run         50mi
#
#          Event number of finishers Athlete performance Athlete gender  \
# 2616900                         36             4:49:16              M
# 2591482                         40             9:19:10              M
#
#          Athlete average speed  Athlete ID  Athlete age
# 2616900                 10.371      222509           23
# 2591482                  8.634      222509           23

# %%
# charts and graph

# %%
import pandas as pd

# %%
sns.histplot(df2['Race_Length'])
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Race_Length', ylabel='Count'>

# %%
sns.histplot(df2, x = df = df.replace([np.inf, -np.inf], np.nan), hue = 'Athlete gender')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.displot(df2[df2['Race_Length'] == '50mi']['Athlete average speed'])
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.violinplot(data=df2 , x='Race_Length', y ='Athlete average speed', hue= 'Athlete gender', split = True , inner = 'quart', linewidth = 1  )
# Out:
# <Axes: xlabel='Race_Length', ylabel='Athlete average speed'>

# %%
sns.lmplot(data=df2, x='Athlete age', y = 'Athlete average speed', hue = 'Athlete gender')
# Out:
# C:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df2.groupby(['Race_Length','Athlete gender'])['Athlete average speed'].mean()
# Out:
# Race_Length  Athlete gender
# 50km         F                 7.083011
#              M                 7.738985
# 50mi         F                 6.834371
#              M                 7.257633
# Name: Athlete average speed, dtype: float64

# %%
df2.head(10)
# Out:
#          Race_Day     Event dates                              Event name  \
# 2746390      2020      17.10.2020              Pumpkin Holler 50 Km Race
# 2577434      2020      12.07.2020  Cremator Ultra 50 Mile Endurance Race
# 2589048      2020      14.03.2020   Peyton's Wild and Wacky 10x5Km Ultra
# 2745828      2020  17.-18.10.2020          Cloudsplitter 100 - 50 Km Run
# 2592144      2020      14.03.2020                Antelope Canyon 50 Mile
# 2652597      2020      19.09.2020      Sangre de Cristo Ultra 50 km Race
# 2623538      2020      15.02.2020               Hagg Lake Trail Runs 50K
# 2678000      2020      22.08.2020             Ghost Town Trail Challenge
# 2723047      2020      08.11.2020        Lost Turkey Trail 50 Mile Ultra
# 2634597      2020      03.10.2020               Rock/Creek StumpJump 50K
#
#         Race_Length  Event number of finishers Athlete performance  \
# 2746390        50km                        105            10:40:56
# 2577434        50mi                          7             7:49:40
# 2589048        50km                         75             3:27:48
# 2745828        50km                         66             8:46:37
# 2592144        50mi                        266            12:59:01
# 2652597        50km                         68             7:30:00
# 2623538        50km                         82             8:08:12
# 2678000        50km                        129             7:42:52
# 2723047        50mi                         17            11:25:40
# 2634597        50km                        224             7:43:46
#
#         Athlete gender  Athlete average speed  Athlete ID  Athlete age
# 2746390              F                  4.681      857217            9
# 2577434              M                 10.280      325504           12
# 2589048              M                 14.437      325504           12
# 2745828              M                  5.697      857061           12
# 2592144              F                  6.198      820935           13
# 2652597              M                  6.667      834818           13
# 2623538              F                  6.145      686139           13
# 2678000              M                  6.481      840194           13
# 2723047              M                  7.041      780296           14
# 2634597              M                  6.469      830186           14
